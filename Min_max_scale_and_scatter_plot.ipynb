# %% [markdown]
# <a href="https://colab.research.google.com/github/zhensongren/learn-ml/blob/master/Min_max_scale_and_scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt 
X, y = make_regression(n_samples=1000, n_features=2, n_informative=2, n_targets=1, random_state=1, noise=5)

# %%
# X1 = X[0].reshape(1,-1)
# X2 = X[1].reshape(1,-1)

# %%
from sklearn.preprocessing import MinMaxScaler
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled_X = scaler.fit_transform(X)

plt.scatter(X[:, 0], X[:, 1])

# %%
plt.scatter(scaled_X[:, 0], scaled_X[:, 1])
